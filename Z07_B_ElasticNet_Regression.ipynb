# %% [markdown]
# # Lasso Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Lasso(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (ElasticNet Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection
from sklearn.linear_model import ElasticNet
 
models = []
predicts = []
names=[]
seed=123
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))
models.append(('ER alpha = 1', make_pipeline(PolynomialFeatures(degree=20), ElasticNet(alpha=1, random_state=seed))))
models.append(('ER alpha = 10000', make_pipeline(PolynomialFeatures(degree=20), ElasticNet(alpha=10000, random_state=seed))))
models.append(('ER alpha = 0.0001', make_pipeline(PolynomialFeatures(degree=20), ElasticNet(alpha=0.0001, random_state=seed))))
 
x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)

x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 20
# ER alpha = 1
# ER alpha = 10000
# ER alpha = 0.0001
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006488426719398116, tolerance: 0.0009243651615937179
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha.

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), ElasticNet(alpha=1, random_state=seed)),
param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7],
'elasticnet__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]},
refit=False)
grid.fit(x, y)
grid.best_params_
# Out:
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08995982961062876, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08160275437796155, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0791943157641341, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.047373183059532635, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030707978019949546, tolerance: 0.0008311335532811798
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07590795841581009, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08025045286414989, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08459737669941277, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.046598682766345156, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0845001444650137, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0859645155611963, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08385562538851363, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.049309458103066646, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016586904613340208, tolerance: 0.0008311335532811798
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08451759855172394, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07871597309983953, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06951222055339251, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04668241918448015, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023415354165541535, tolerance: 0.0008311335532811798
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07897554916277859, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0659652794800022, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05369297402533846, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04255188348561342, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022651660161566316, tolerance: 0.0008311335532811798
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03714952239419303, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03876382467423725, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03637919161433073, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019633369850306476, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001036987738822992, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007182458920580587, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014915915935040935, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015787446305936093, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02709613815485977, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02780204254040311, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010456283674150926, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022973865860163464, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03816305557733163, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05128785458449983, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02135412217834532, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03344914784662657, tolerance: 0.0003836480376371998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04036757147312348, tolerance: 0.0008184492574631078
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04132419470985789, tolerance: 0.0008996306130320419
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jansk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022867132665104095, tolerance: 0.0005514326620354933
#   model = cd_fast.enet_coordinate_descent(
# {'elasticnet__alpha': 0.0001, 'polynomialfeatures__degree': 4}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9
